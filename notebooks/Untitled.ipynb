# %%
# !pip install loguru

# %%
import src.configs.config
from loguru import logger
from src.decorators.time_decorator import log_execution_time
import time

# %%
import src.configs.config
from loguru import logger

logger.info("hello")
logger.info("hello2")
# Out:
# 2025-11-01 19:22:33.549 | INFO     | __main__:<module>:4 - hello
# 2025-11-01 19:22:33.551 | INFO     | __main__:<module>:5 - hello2

# %%
from loguru import logger

# %%
logger.info("hello")

# %%
@log_execution_time
def func1():
    time.sleep(1)
    logger.info(" func1 done!")

# %%
func1()
