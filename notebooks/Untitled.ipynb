# %%
# !pip install loguru
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import src.configs.config
from loguru import logger

logger.info("hello")
logger.info("hello2")
# Out:
# 2025-11-01 07:20:13.538 | INFO     | __main__:<module>:4 - hello
# 2025-11-01 07:20:13.539 | INFO     | __main__:<module>:5 - hello2

# %%
from loguru import logger

# %%
logger.info("hello")
# Out:
# 2025-11-01 07:21:24.241 | INFO     | __main__:<module>:1 - hello
