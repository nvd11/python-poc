# %%
import sys
import os

# 打印当前的 Python 搜索路径
print('--- sys.path ---')
for path in sys.path:
    print(path)
print('\n--- 项目根目录是否在路径中? ---')
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root in sys.path:
    print(f'成功: {project_root} 已在 sys.path 中。')
else:
    print(f'失败: {project_root} 不在 sys.path 中。')

# %%
# 尝试从 src 目录导入模块
try:
    from src.decorators.time_decorator import time_this
    print('\n导入测试成功！可以从 src 目录正常导入模块。')
except ImportError as e:
    print(f'\n导入测试失败: {e}')
